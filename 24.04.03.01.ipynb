# %%
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv('df1.csv',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2.csv')

# %%
df2
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y
# 5  0.286043  0.593465  0.907307  0.637898  x
# 6  0.430436  0.166230  0.469383  0.497701  z
# 7  0.312296  0.502823  0.806609  0.850519  z
# 8  0.187765  0.997075  0.895955  0.530390  x
# 9  0.908162  0.232726  0.414138  0.432007  y

# %%
df1['A'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.hist(edgecolor='K').autoscal(enble=True, axis='both', tight=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df1['A'].plot.hist(edgecolor='K').autoscal(enble=True, axis='both', tight=True)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/plotting/_core.py:1412, in PlotAccessor.hist(self, by, bins, **kwargs)
#    1350 def hist(
#    1351     self, by: IndexLabel | None = None, bins: int = 10, **kwargs
#    1352 ) -> PlotAccessor:
#    1353     """
#    1354     Draw one histogram of the DataFrame's columns.
#    1355
#    (...)
#    1410         >>> ax = df.plot.hist(column=["age"], by="gender", figsize=(10, 8))
#    1411     """
# -> 1412     return self(kind="hist", by=by, bins=bins, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/plotting/_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
# ...

# %%
df1['A'].plot.hist[grid = True]
# Out:
#   Cell In[44], line 1
#     df1['A'].plot.hist[grid = True]
#                        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
df2.plot.barh()
# Out:
# <Axes: >

# %%
df2.plot.line(y=['a','b','c'],figsize=(10,4),lw=4)
# Out:
# <Axes: >

# %%
df2.plot.area(stacked=False,alpha=0.4)
# Out:
# <Axes: >

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df1.plot.scatter(x='A',y='B',s='C',c='C', alpha=0.9)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df2.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
import numpy as np
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df.plot.scatter(x='a',y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a',y='b',gridsize=25)
# Out:
# <Axes: xlabel='a', ylabel='b'>
