# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
import statsmodels.api as sm

# %%
from statsmodels.tsa.stattools import acovf,acf,pacf,pacf_yw,pacf_ols

# %%
df1 = pd.read_csv('../Data/airline_passengers.csv',index_col = 'Month',parse_dates=True)
df1.index.freq = 'MS'

# %%
df2 = pd.read_csv('../Data/DailyTotalFemaleBirths.csv',index_col='Date',parse_dates=True)
df2.index.freq='D'

# %%
df1.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %%
df2.head()
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.DataFrame({'a':[13,5,11,12,9]})

# %%
df
# Out:
#     a
# 0  13
# 1   5
# 2  11
# 3  12
# 4   9

# %%
acf(df['a'])
# Out:
# array([ 1.   , -0.5  , -0.2  ,  0.275, -0.075])

# %%
array([1. , -0.5 , -0.2, 0.275, -0.075])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 array([1. , -0.5 , -0.2, 0.275, -0.075])
#
# NameError: name 'array' is not defined

# %%
pacf_yw(df['a'],nlags=4,method='unbiased')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 pacf_yw(df['a'],nlags=4,method='unbiased')
#
# File /opt/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/stattools.py:752, in pacf_yw(x, nlags, method)
#     749 if nlags is None:
#     750     nlags = min(int(10 * np.log10(nobs)), nobs - 1)
# --> 752 method = string_like(method, "method", options=("adjusted", "mle"))
#     753 pacf = [1.0]
#     754 with warnings.catch_warnings():
#
# File /opt/anaconda3/lib/python3.11/site-packages/statsmodels/tools/validation/validation.py:446, in string_like(value, name, optional, options, lower)
#     442     options_text = "'" + "', '".join(options) + "'"
#     443     msg = "{0}{1} must be one of: {2}".format(
#     444         extra_text, name, options_text
#     445     )
# --> 446     raise ValueError(msg)
#     447 return value
#
# ValueError: method must be one of: 'adjusted', 'mle'

# %%
pacf_ols(df['a'],nlags=4)
# Out:
# array([ 1.        , -0.49677419, -0.43181818,  0.53082621,  0.25434783])

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(df1['Thousands of Passengers'])
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
df1.plot();

# %%
plot_acf(df1,lags=40);

# %%
plot_acf(df2,lags=40)

# %%
plot_pacf(df2,lags=40,title='Daily Female Births')
